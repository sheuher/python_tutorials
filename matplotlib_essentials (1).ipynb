# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

# %% [markdown]
# # Making Plots Actually Look Nice
#
# If one has SciencePlots (https://github.com/garrettj403/SciencePlots) installed has additional options for matplotlib

# %%
plt.style.use(['science', 'notebook', 'grid'])

# %% [markdown]
# # Quick Plotting

# %% [markdown]
# ## Line Plots

# %% [markdown]
# Simple plotting commands to look at data quickly

# %%
x = np.linspace(0, 15, 30)
y = np.sin(x) + 0.1*np.random.randn(len(x))

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, '-')

# %%
plt.plot(x, y, '--')

# %%
plt.plot(x, y, 'o--', color='purple', lw=0.1, ms=10)

#color - color
#lw - line thickness
#ms - marker size

# %% [markdown]
# Figure size

# %%
plt.figure(figsize=(8,3))
plt.plot(x, y)

# %% [markdown]
# Axis labels

# %%
plt.figure(figsize=(8, 3))
plt.plot(x, y, 'o--', color='purple', lw=0.7, ms=5)
plt.xlabel('Times [s]')
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
# Out:
# Text(0.5, 1.0, 'Voltage in 3rd Electrode')

# %% [markdown]
# Legend

# %%
plt.figure(figsize=(8, 3))
plt.plot(x, y, color="blue", label="Component 1")
plt.xlabel('Times [s]')
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')
plt.legend(loc='upper right', fontsize = 11)

# legend with fontsize and location

# %% [markdown]
# Easy to have multiple lines on same plot

# %%
x2 = np.linspace(0, 15, 100)
y2 = np.sin(x2)

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'o', color='purple', lw=0.7, ms=5, label="Component 1")
plt.plot(x2, y2, '-', color='green', lw=0.8, label = 'Componenet 2')
plt.xlabel('Times [s]')
plt.ylabel('Voltage [V]')
plt.title('Voltage in 3rd Electrode')

plt.legend(loc='upper right', fontsize = 11)

# %% [markdown]
# $x$ and $y$ limits

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'o', color='purple', lw=0.7, ms=5, label="Component 1")
plt.plot(x2, y2, '-', color='green', lw=0.8, label = 'Componenet 2')
plt.xlabel('Times [s]')
plt.ylabel('Voltage [V]')
plt.ylim(top=1.6)
plt.legend(loc='upper right', fontsize = 11, ncol=2)

#change y limit and colomn for legend

# %% [markdown]
# ## Histograms

# %%
res = np.random.randn(1000)*0.2 + 0.4

# %% [markdown]
# Quick Histogram

# %%
plt.figure(figsize=(8,3))
a = plt.hist(res, bins=30, density=True) # density - true: area = 1
plt.show()

# %%
a
# Out:
# (array([ 2.,  3.,  3.,  6., 14., 16., 20., 20., 32., 51., 59., 60., 87.,
#         81., 69., 72., 69., 61., 62., 55., 43., 31., 20., 24., 12., 12.,
#          5.,  1.,  7.,  3.]),
#  array([-0.18087823, -0.14134619, -0.10181416, -0.06228213, -0.02275009,
#          0.01678194,  0.05631397,  0.095846  ,  0.13537804,  0.17491007,
#          0.2144421 ,  0.25397413,  0.29350617,  0.3330382 ,  0.37257023,
#          0.41210227,  0.4516343 ,  0.49116633,  0.53069836,  0.5702304 ,
#          0.60976243,  0.64929446,  0.6888265 ,  0.72835853,  0.76789056,
#          0.80742259,  0.84695463,  0.88648666,  0.92601869,  0.96555073,
#          1.00508276]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# Differnt style of bins (useful for plotting multiple histograms)

# %%
res2 = np.random.randn(1000)*0.2 + 0.4

# %%
plt.figure(figsize=(8,3))
a = plt.hist(res, bins=30, density=True, histtype = 'step')
a = plt.hist(res2, bins=30, density=True, histtype = 'step') 
plt.show()

# %% [markdown]
# # A More Advanced API
#
# For more complicated plots, such as
#
# * Multiple subplots on 1 figure
# * Conveniently adding text to plots
# * Creating animations
#
# one needs to use a slightly more advanced API

# %% [markdown]
# ## Single Axes in one Figure

# %%
fig, ax = plt.subplots(1, 1, figsize = (12, 4))
ax.plot(x, y, 'o--')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
# Out:
# Text(0, 0.5, 'ylabel')

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

# %% [markdown]
# ## Multiple axes in 1 figure

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 12))
ax = axes[0][0]
ax.plot(x, y, 'o--', label = 'comp1')
ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')
ax.text(0.1, 0.1, 'text here', transform=ax.transAxes) # add text, with correct orientation?
ax.tick_params(axis='both', labelsize=10) # axis numbers here are smaller

ax = axes[1][1]
ax = plt.hist(res, bins=30, density=True, histtype = 'step', label = "comp2")
#ax.legend()
#ax.set_title("Histogram")

plt.show()

# %% [markdown]
# # Example
#
# Creating the following plot

# %%
res_a1 = 0.2*np.random.randn(1000)*0.2 + 0.4
res_b1 = 0.25*np.random.randn(1000)*0.2 + 0.4
res_a2 = 0.21*np.random.randn(1000)*0.2 + 0.4
res_b2 = 0.22*np.random.randn(1000)*0.2 + 0.4

# %% [markdown]
# Change number of bins

# %% [markdown]
# Good habit to come up with complicated strings beforehand

# %%
textstr1 = '\n'.join((
    r'$\sigma_a-%.4f$' % (np.std(res_a1)),
    r'$\sigma_a-%.4f$' % (np.std(res_b1))
))

textstr2 = '\n'.join((
    r'$\sigma_a-%.4f$' % (np.std(res_a2)),
    r'$\sigma_a-%.4f$' % (np.std(res_b2))
))

# %%
textstr1
# Out:
# '$\\sigma_a-0.0385$\n$\\sigma_a-0.0505$'

# %% [markdown]
# Make plot

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 3.5))
ax = axes[0]
ax.hist(res_a1, bins=30, density=True, histtype='step', label='a', color='blue') 
ax.hist(res_b1, bins=30, density=True, histtype='step', label='b', color='red') 
#ax.legend(loc="upper right", fancybox=False, edgecolor='black')
ax.text(0.05, 0.81, textstr1, transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylabel('Density')
ax.set_title('Trial 1')
fig.text(0.5, -0.04, '$\Delta E$ [Joules]', ha='center', fontsize=20)

ax = axes[1]
ax.hist(res_a2, bins=30, density=True, histtype='step', label='a', color='blue') 
ax.hist(res_b2, bins=30, density=True, histtype='step', label='b', color='red') 
ax.legend(loc="upper right", fancybox=False, edgecolor='black')
ax.text(0.05, 0.81, textstr2, transform=ax.transAxes, bbox=dict(facecolor='white', edgecolor='black'))
#ax.set_ylabel('Density')
ax.set_title('Trial 2')
fig.text(0.5, -0.04, '$\Delta E$ [Joules]', ha='center', fontsize=20)
plt.savefig('plot.png', dpi=200)

# %% [markdown]
# # 2D Plots

# %% [markdown]
# Generate some data

# %%
_ = np.linspace(-1, 1, 100)
x, y = np.meshgrid(_,_)
z = x**2 + x*y

# %%
z
# Out:
# array([[ 2.00000000e+00,  1.93980206e+00,  1.88042037e+00, ...,
#         -3.87715539e-02, -1.97938986e-02,  0.00000000e+00],
#        [ 1.97979798e+00,  1.92000816e+00,  1.86103459e+00, ...,
#         -1.93857770e-02,  1.11022302e-16,  2.02020202e-02],
#        [ 1.95959596e+00,  1.90021426e+00,  1.84164881e+00, ...,
#          2.22044605e-16,  1.97938986e-02,  4.04040404e-02],
#        ...,
#        [ 4.04040404e-02,  1.97938986e-02, -2.22044605e-16, ...,
#          1.84164881e+00,  1.90021426e+00,  1.95959596e+00],
#        [ 2.02020202e-02, -1.11022302e-16, -1.93857770e-02, ...,
#          1.86103459e+00,  1.92000816e+00,  1.97979798e+00],
#        [ 0.00000000e+00, -1.97938986e-02, -3.87715539e-02, ...,
#          1.88042037e+00,  1.93980206e+00,  2.00000000e+00]])

# %% [markdown]
# ## Filled-in contour plots

# %%
plt.contourf(x, y, z, levels=30, cmap='plasma') #for divergence function (x^-1) it is useful to use vmax, vmin
plt.colorbar(label = 'asd')

# %% [markdown]
# Can make them more dense ny changing `levels` and also can change colormap
#
# * See https://matplotlib.org/stable/tutorials/colors/colormaps.html#sphx-glr-tutorials-colors-colormaps-py
#
# Can use `vmin` and `vmax` to adjust the color range
#
# * See https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contour.html for all settings

# %% [markdown]
# ## Contour Plot

# %% [markdown]
# Sometimes, the following is preferred:

# %%
cs = plt.contour(x, y, z, levels=50)
plt.clabel(cs, fontsize = 8)
# Out:
# <a list of 84 text.Text objects>

# %% [markdown]
# ## 3D Surface Plot

# %% [markdown]
# 3D Surface Plot (Generally not preferred). However, they tend to work well in animations (we'll get to this later)

# %%
fig, ax = plt.subplots(subplot_kw={'projection' :'3d'})
ax.plot_surface(x, y, z, cmap = 'coolwarm')

# %% [markdown]
# ## StreamPlots

# %% [markdown]
# For plotting vector fields

# %%
w = 3
_ = np.linspace(-3, 3, 100)
X, Y = np.meshgrid(_,_)
U = -1 -X**2 + Y
V = 1 + X - Y**2
speed = np.sqrt(U**2 + V**2)

# %%
fig, axes = plt.subplots(2, 2, figsize=(7, 7))
ax = axes[0][0]
ax.streamplot(X, Y, U, V)
#without sense of magnitude

ax = axes[0][1]
ax.streamplot(X, Y, U, V)
ax.streamplot(X, Y, U, V, color=speed)
#not good enough 

ax = axes[1][0]
lw = 5*speed / speed.max()
ax.streamplot(X, Y, U, V, linewidth=lw)
# much aestheticly looking

ax = axes[1][1]
lw = 5*speed / speed.max()
seedpoints=np.array([[0,1], [1,0]])
ax.streamplot(X, Y, U, V, color=U, linewidth=2, cmap='autumn',
    start_points=seedpoints)
#final plot

# %% [markdown]
# # Image Reading

# %%
im = plt.imread('/Users/sheuh/Downloads/flower.png.png')

# %% [markdown]
# Plot image

# %%
plt.imshow(im)

# %% [markdown]
# # Animations

# %% [markdown]
# Animations require relating the time of your problem to the frame of the animation, then specifying the frames per second
#
# * Below is a $\sin$ wave moving at 3m/s. Translate this into an animation

# %%
def f(f,t):
    return np.sin(x-3*t)

x = np.linspace(0, 10*np.pi, 1000)

# %%
plt.plot(x, f(x, 0))
plt.plot(x, f(x, 0.1))

# %%
plt.plot(x, F[1])

# %% [markdown]
# Create animation

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([], [])
time_text = ax.text(0.65, 0.95, '', fontsize=15,
                    bbox=dict(facecolor='white', edgecolor='black'), 
                    transform=ax.transAxes)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, F[i])
    time_text.set_text('t={:.2f}'.format(i/60))
    
ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\sheuh\Downloads\matplotlib_essentials (1).ipynb Cell 73 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=10'>11</a>     time_text.set_text('t={:.2f}'.format(i/60))
#      <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=12'>13</a> ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=13'>14</a> ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:503, in PillowWriter.setup(self, fig, outfile, dpi)
#     502 def setup(self, fig, outfile, dpi=None):
# --> 503     super().setup(fig, outfile, dpi=dpi)
#     504     self._frames = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:195, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     181 """
#     182 Setup for writing the movie file.
#     183
#    (...)
#     192     in pixels of the resulting movie file.
#     193 """
#     194 # Check that path is valid
# --> 195 Path(outfile).parent.resolve(strict=True)
#     196 self.outfile = outfile
#     197 self.fig = fig
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:993, in Path.resolve(self, strict)
#     990         raise RuntimeError("Symlink loop from %r" % e.filename)
#     992 try:
# --> 993     s = os.path.realpath(self, strict=strict)
#     994 except OSError as e:
#     995     check_eloop(e)
#
# File <frozen ntpath>:696, in realpath(path, strict)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'c:\\Users\\sheuh\\Downloads\\images'
# Error in callback <function _draw_all_if_interactive at 0x00000263928FE3E0> (for post_execute):
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\figure.py:3164, in Figure.draw(self, renderer)
#    3161 finally:
#    3162     self.stale = False
# -> 3164 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:912, in Animation._start(self, *args)
#     909 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     911 # Now do any initial draw
# --> 912 self._init_draw()
#     914 # Add our callback for stepping the animation and
#     915 # actually start the event_source.
#     916 self.event_source.add_callback(self._step)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1749, in FuncAnimation._init_draw(self)
#    1741         warnings.warn(
#    1742             "Can not start iterating the frames for the initial draw. "
#    1743             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1746             "it may be exhausted due to a previous display or save."
#    1747         )
#    1748         return
# -> 1749     self._draw_frame(frame_data)
#    1750 else:
#    1751     self._drawn_artists = self._init_func()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1768, in FuncAnimation._draw_frame(self, framedata)
#    1764     self._save_seq = self._save_seq[-self._save_count:]
#    1766 # Call the func with framedata and args. If blitting is desired,
#    1767 # func needs to return a sequence of any artists that were modified.
# -> 1768 self._drawn_artists = self._func(framedata, *self._args)
#    1770 if self._blit:
#    1772     err = RuntimeError('The animation function must return a sequence '
#    1773                        'of Artist objects.')
#
# c:\Users\sheuh\Downloads\matplotlib_essentials (1).ipynb Cell 73 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=8'>9</a> def animate(i):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=9'>10</a>     ln1.set_data(x, F[i])
#      <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y150sZmlsZQ%3D%3D?line=10'>11</a>     time_text.set_text('t={:.2f}'.format(i/60))
#
# NameError: name 'F' is not defined

# %%
fig, ax = plt.subplots(1,1, figsize=(8,4))
ln1, = plt.plot([],[])
time_text = ax.text(0.65, 0.95, '', fontsize=15, bbox=dict(facecolor='white', edgecolor='black'), transform=ax.transAxes)

ax.set_xlim(0, 10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ln1.set_data(x, f(x, 1/50*i))
    time_text.set_text('t={:.2f}'.format(i/50))

ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)

## how to make one actually!!!
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\sheuh\Downloads\matplotlib_essentials (1).ipynb Cell 74 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y134sZmlsZQ%3D%3D?line=9'>10</a>     time_text.set_text('t={:.2f}'.format(i/50))
#      <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y134sZmlsZQ%3D%3D?line=11'>12</a> ani = animation.FuncAnimation(fig, animate, frames=240, interval=50)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y134sZmlsZQ%3D%3D?line=12'>13</a> ani.save('images/ani.gif',writer='pillow',fps=50,dpi=100)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:503, in PillowWriter.setup(self, fig, outfile, dpi)
#     502 def setup(self, fig, outfile, dpi=None):
# --> 503     super().setup(fig, outfile, dpi=dpi)
#     504     self._frames = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:195, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     181 """
#     182 Setup for writing the movie file.
#     183
#    (...)
#     192     in pixels of the resulting movie file.
#     193 """
#     194 # Check that path is valid
# --> 195 Path(outfile).parent.resolve(strict=True)
#     196 self.outfile = outfile
#     197 self.fig = fig
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:993, in Path.resolve(self, strict)
#     990         raise RuntimeError("Symlink loop from %r" % e.filename)
#     992 try:
# --> 993     s = os.path.realpath(self, strict=strict)
#     994 except OSError as e:
#     995     check_eloop(e)
#
# File <frozen ntpath>:696, in realpath(path, strict)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'c:\\Users\\sheuh\\Downloads\\images'

# %% [markdown]
# The animation function can be used in other ways too. One can create 3D rotating gifs of surfaces.

# %%
_ = np.linspace(-1,1,100)
x, y = np.meshgrid(_,_)
z = x**2 + x*y

# %%
plt.style.use(['default'])

# %%
fig, ax = plt.subplots(subplot_kw={'projection':'3d'})
ax.plot_surface(x,y,z,cmap='coolwarm', linewidth=0, antialiased=False)
ax.set_xlim(0,10*np.pi)
ax.set_ylim(-1.5, 1.5)

def animate(i):
    ax.view_init(elev=10, azim=3*i)
    
ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
ani.save('images/ani2.gif',writer='pillow',fps=30,dpi=100)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\sheuh\Downloads\matplotlib_essentials (1).ipynb Cell 78 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y140sZmlsZQ%3D%3D?line=6'>7</a>     ax.view_init(elev=10, azim=3*i)
#       <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y140sZmlsZQ%3D%3D?line=8'>9</a> ani = animation.FuncAnimation(fig, animate, frames=120, interval=50)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sheuh/Downloads/matplotlib_essentials%20%281%29.ipynb#Y140sZmlsZQ%3D%3D?line=9'>10</a> ani.save('images/ani2.gif',writer='pillow',fps=30,dpi=100)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:1089, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1085 savefig_kwargs['transparent'] = False   # just to be safe!
#    1086 # canvas._is_saving = True makes the draw_event animation-starting
#    1087 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1088 # widget (both are likewise done in savefig()).
# -> 1089 with writer.saving(self._fig, filename, dpi), \
#    1090      cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None):
#    1091     for anim in all_anim:
#    1092         anim._init_draw()  # Clear the initial frame
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:240, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     235     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#     236               "frame size to vary, which is inappropriate for "
#     237               "animation.")
#     239 # This particular sequence is what contextlib.contextmanager wants
# --> 240 self.setup(fig, outfile, dpi, *args, **kwargs)
#     241 with mpl.rc_context({'savefig.bbox': None}):
#     242     try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:503, in PillowWriter.setup(self, fig, outfile, dpi)
#     502 def setup(self, fig, outfile, dpi=None):
# --> 503     super().setup(fig, outfile, dpi=dpi)
#     504     self._frames = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\animation.py:195, in AbstractMovieWriter.setup(self, fig, outfile, dpi)
#     181 """
#     182 Setup for writing the movie file.
#     183
#    (...)
#     192     in pixels of the resulting movie file.
#     193 """
#     194 # Check that path is valid
# --> 195 Path(outfile).parent.resolve(strict=True)
#     196 self.outfile = outfile
#     197 self.fig = fig
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1520.0_x64__qbz5n2kfra8p0\Lib\pathlib.py:993, in Path.resolve(self, strict)
#     990         raise RuntimeError("Symlink loop from %r" % e.filename)
#     992 try:
# --> 993     s = os.path.realpath(self, strict=strict)
#     994 except OSError as e:
#     995     check_eloop(e)
#
# File <frozen ntpath>:696, in realpath(path, strict)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'c:\\Users\\sheuh\\Downloads\\images'
